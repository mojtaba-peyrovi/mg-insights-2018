# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# %%
website = pd.read_excel("visit-revenue-Jan-Feb-Mar-2018.xlsx",sheetname='website-view-lead-sale')
# Out:
# c:\users\mojiway\appdata\local\programs\python\python36-32\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
website
# Out:
#     year      month  website views  website leads  website sale
# 0   2016    January         110547           2253            55
# 1   2016   February         115756           2187            66
# 2   2016      March         165546           3880           115
# 3   2016      April         162518           2721           111
# 4   2016        May         173053           2958            98
# 5   2016       June         134284           1694            81
# 6   2016       July         125338           1481            80
# 7   2016     August         131513           1421            72
# 8   2016  September         125421           1397            76
# 9   2016    October         113984           1094            64
# 10  2016   November         135638           1584            82
# 11  2016   December         124000           1089            82
# 12  2017    January         144869           1246            49
# 13  2017   February         123297            865            60
# ...

# %%
sns.distplot(website['website leads'],bins=10)
# Out:
# c:\users\mojiway\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.figure(figsize=(120,120))
sns.jointplot(x='website leads',y='website sale',data=website,kind='kde')

# %%
plt.figure(figsize=(80,30))
sns.set_style("whitegrid")
g = sns.lmplot(x='website leads',y='website sale',data=website,palette="hot")

# %%
sns.pairplot(data=website)

# %%
revenue = pd.read_excel("mg-insights-apr-2018.xlsx",sheetname='Revenue Analysis',dtype={'website':int,'other_sources':int,'total_revenue':int,'year':object},thousands=',')
# Out:
# c:\users\mojiway\appdata\local\programs\python\python36-32\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
revenue.dtypes
# Out:
# year             object
# month            object
# website           int32
# other_sources     int32
# total_revenue     int32
# dtype: object

# %%
revenue
# Out:
#     year      month  website  other_sources  total_revenue
# 0   2016    January    97481          54806         152288
# 1   2016   February   112528          75145         187674
# 2   2016      March   210964          87971         298935
# 3   2016      April   200507          72015         272523
# 4   2016        May   183488          75188         258676
# 5   2016       June   164660         150567         315228
# 6   2016       July   151401          99291         250692
# 7   2016     August   138488          59758         198246
# 8   2016  September   138494          72192         210686
# 9   2016    October   131585          55926         187511
# 10  2016   November   175091          63816         238907
# 11  2016   December   166605          80726         247332
# 12  2017    January    91746          77691         169438
# 13  2017   February   122679          69290         191969
# 14  2017      March    97769          68938         166707
# ...

# %%
revenue['total_revenue'] = revenue.apply(lambda x: "{:,}".format(x['total_revenue']), axis=1)

# %%
revenue
# Out:
#     year      month  website other_sources total_revenue
# 0   2016    January   97,481        54,806       152,288
# 1   2016   February  112,528        75,145       187,674
# 2   2016      March  210,964        87,971       298,935
# 3   2016      April  200,507        72,015       272,523
# 4   2016        May  183,488        75,188       258,676
# 5   2016       June  164,660       150,567       315,228
# 6   2016       July  151,401        99,291       250,692
# 7   2016     August  138,488        59,758       198,246
# 8   2016  September  138,494        72,192       210,686
# 9   2016    October  131,585        55,926       187,511
# 10  2016   November  175,091        63,816       238,907
# 11  2016   December  166,605        80,726       247,332
# 12  2017    January   91,746        77,691       169,438
# 13  2017   February  122,679        69,290       191,969
# 14  2017      March   97,769        68,938       166,707
# ...

# %%
# Out:
#     year      month  website  other_sources  total_revenue
# 0   2016    January    97481          54806         152288
# 1   2016   February   112528          75145         187674
# 2   2016      March   210964          87971         298935
# 3   2016      April   200507          72015         272523
# 4   2016        May   183488          75188         258676
# 5   2016       June   164660         150567         315228
# 6   2016       July   151401          99291         250692
# 7   2016     August   138488          59758         198246
# 8   2016  September   138494          72192         210686
# 9   2016    October   131585          55926         187511
# 10  2016   November   175091          63816         238907
# 11  2016   December   166605          80726         247332
# 12  2017    January    91746          77691         169438
# 13  2017   February   122679          69290         191969
# 14  2017      March    97769          68938         166707
# ...

# %%
revenue = pd.read_excel("mg-insights-apr-2018.xlsx",sheetname='Revenue Analysis',dtype={'website':int,'other_sources':int,'total_revenue':int,'year':object},thousands=',')
# Out:
# c:\users\mojiway\appdata\local\programs\python\python36-32\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
revenue['total_revenue'] = revenue.apply(lambda x: "{:,}".format(x['total_revenue']), axis=1)

# %%
revenue
# Out:
#     year      month  website  other_sources total_revenue
# 0   2016    January    97481          54806       152,288
# 1   2016   February   112528          75145       187,674
# 2   2016      March   210964          87971       298,935
# 3   2016      April   200507          72015       272,523
# 4   2016        May   183488          75188       258,676
# 5   2016       June   164660         150567       315,228
# 6   2016       July   151401          99291       250,692
# 7   2016     August   138488          59758       198,246
# 8   2016  September   138494          72192       210,686
# 9   2016    October   131585          55926       187,511
# 10  2016   November   175091          63816       238,907
# 11  2016   December   166605          80726       247,332
# 12  2017    January    91746          77691       169,438
# 13  2017   February   122679          69290       191,969
# 14  2017      March    97769          68938       166,707
# ...

# %%
data = revenue.pivot_table(index='month',columns='year',values='website')

# %%
data
# Out:
# year           2016      2017      2018
# month
# April      200507.0  119366.0       NaN
# August     138488.0  119517.0       NaN
# December   166605.0   90313.0       NaN
# February   112528.0  122679.0  160655.0
# January     97481.0   91746.0  156827.0
# July       151401.0   58935.0       NaN
# June       164660.0   72507.0       NaN
# March      210964.0   97769.0  137101.0
# May        183488.0   82258.0       NaN
# November   175091.0  116928.0       NaN
# October    131585.0   93514.0       NaN
# September  138494.0   83545.0       NaN

# %%
allData
# Out:
#     year      month  website views  website leads  website sale  \
# 0   2016    January         110547           2253            55
# 1   2016   February         115756           2187            66
# 2   2016      March         165546           3880           115
# 3   2016      April         162518           2721           111
# 4   2016        May         173053           2958            98
# 5   2016       June         134284           1694            81
# 6   2016       July         125338           1481            80
# 7   2016     August         131513           1421            72
# 8   2016  September         125421           1397            76
# 9   2016    October         113984           1094            64
# 10  2016   November         135638           1584            82
# 11  2016   December         124000           1089            82
# 12  2017    January         144869           1246            49
# 13  2017   February         123297            865            60
# ...

# %%
sns.pairplot(allData)

# %%
sns.lmplot(x='all sale',y='website sale',data=allData)

# %%
sns.lmplot(x='total revenue',y='revenue from website',data=allData)

# %%
sns.lmplot(x='facebook views',y='facebook sale',data=allData)

# %%
sns.distplot(allData['total revenue'],bins=10)
# Out:
# c:\users\mojiway\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='total revenue',y='revenue from website',data=allData,kind='kde')

# %%
sns.lmplot(x='all sale',y='total revenue',data=allData)

# %%
sns.lmplot(x='website views',y='revenue from website',data=allData)

# %%
allData.dtypes
# Out:
# year                      object
# month                     object
# website views              int32
# website leads              int32
# website sale               int32
# website conversion(%)    float64
# revenue from website       int32
# facebook views             int32
# facebook leads             int32
# facebook sale              int32
# facebook conversion      float64
# all leads                  int32
# all sale                   int32
# total conversion         float64
# total revenue              int32
# dtype: object
