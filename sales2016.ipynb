# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
sales2016=pd.read_excel("sales2016.xlsx")

# %%
sales2016
# Out:
#       year  month nationality   revenueTHB           status  \
# 0     2016      1        Thai  2058.391000  PAY-Installment
# 1     2016      1        Thai  2518.634600          PAYMENT
# 2     2016      1        Thai   744.592000          PAYMENT
# 3     2016      1   Foreigner  3450.126000          PAYMENT
# 4     2016      1        Thai  2082.866200          PAYMENT
# 5     2016      1        Thai  1822.614200          PAYMENT
# 6     2016      1   Foreigner  1800.000000          PAYMENT
# 7     2016      1        Thai  1754.760200  PAY-Installment
# 8     2016      1        Thai  2058.391000          PAYMENT
# 9     2016      1        Thai  1413.038000          PAYMENT
# 10    2016      1   Foreigner  2240.249400          PAYMENT
# 11    2016      1        Thai  1741.311200  PAY-Installment
# 12    2016      1        Thai  2260.114200  PAY-Installment
# 13    2016      1        Thai  2336.593000          PAYMENT
# 14    2016      1        Thai  1890.498000          PAYMENT
# ...

# %%
plt.figure(figsize=(20,8))
sns.countplot(x='nationality',data=sales2016,hue='status')
sns.set_context('poster')

# %%
fp = sales2016.pivot_table(index='month',columns='year',values='revenueTHB',aggfunc=np.sum)

# %%
fp
# Out:
# year            2016           2017           2018
# month
# 1      152288.012400  169438.026616  264848.496449
# 2      187674.484700  191969.458602  164129.319455
# 3      298935.408200  166707.472755  151699.759865
# 4      272523.276800  174628.629198    7226.734187
# 5      258676.271035  162345.481226            NaN
# 6      315228.434003  152235.124065            NaN
# 7      250692.539969  116247.926273            NaN
# 8      198246.904727  183906.666218            NaN
# 9      210686.756241  147783.382077            NaN
# 10     187511.757373  143886.260242            NaN
# 11     238907.938990  186103.086789            NaN
# 12     247332.065056  152223.004416            NaN

# %%
plt.figure(figsize=(20,8))
sns.heatmap(fp,cmap='YlGn',linecolor='white',linewidth=1,annot=True,fmt='g')

# %%
fp2 = sales2016.pivot_table(index='Insurer',columns='year',values='revenueTHB',aggfunc=np.sum)

# %% [raw]
# fp2

# %%
plt.figure(figsize=(20,20))
sns.heatmap(fp2,cmap='YlGn',linecolor='white',linewidth=1,annot=True,fmt='g')

# %%
fp = sales2016.pivot_table(index='month',columns='year',values='revenueTHB',aggfunc=np.sum)

# %%
fp
# Out:
# year            2016           2017           2018
# month
# 1      152288.012400  169438.026616  264848.496449
# 2      187674.484700  191969.458602  164129.319455
# 3      298935.408200  166707.472755  151699.759865
# 4      272523.276800  174628.629198    7226.734187
# 5      258676.271035  162345.481226            NaN
# 6      315228.434003  152235.124065            NaN
# 7      250692.539969  116247.926273            NaN
# 8      198246.904727  183906.666218            NaN
# 9      210686.756241  147783.382077            NaN
# 10     187511.757373  143886.260242            NaN
# 11     238907.938990  186103.086789            NaN
# 12     247332.065056  152223.004416            NaN

# %%
sales = sales2016.drop(column['year'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-12cdcb6d3ee6> in <module>()
# ----> 1 sales = sales2016.drop(column['year'],axis=1)
#
# NameError: name 'column' is not defined

# %%
sales
# Out:
#       year  month nationality   revenueTHB           status  \
# 0     2016      1        Thai  2058.391000  PAY-Installment
# 2     2016      1        Thai   744.592000          PAYMENT
# 3     2016      1   Foreigner  3450.126000          PAYMENT
# 4     2016      1        Thai  2082.866200          PAYMENT
# 5     2016      1        Thai  1822.614200          PAYMENT
# 6     2016      1   Foreigner  1800.000000          PAYMENT
# 7     2016      1        Thai  1754.760200  PAY-Installment
# 8     2016      1        Thai  2058.391000          PAYMENT
# 9     2016      1        Thai  1413.038000          PAYMENT
# 10    2016      1   Foreigner  2240.249400          PAYMENT
# 11    2016      1        Thai  1741.311200  PAY-Installment
# 12    2016      1        Thai  2260.114200  PAY-Installment
# 13    2016      1        Thai  2336.593000          PAYMENT
# 14    2016      1        Thai  1890.498000          PAYMENT
# 15    2016      1        Thai  2105.970000          PAYMENT
# ...

# %%
df = pd.read_excel('visits-Jan-Feb-Mar-2018.xlsx')

# %%
df
# Out:
#     month  day  Page Views  Organic Searches  Avg. Time on Page
# 0       1    1        3106              1738         150.711111
# 1       1    2        4944              2535         112.363768
# 2       1    3        6845              3612         117.895123
# 3       1    4        6653              3599         138.593058
# 4       1    5        6544              3274         105.757796
# 5       1    6        5231              2716         118.910029
# 6       1    7        4963              2513         113.705513
# 7       1    8        6140              3321         135.353093
# 8       1    9        6108              3125         124.708286
# 9       1   10        5588              2955         128.076455
# 10      1   11        5391              2880         109.853411
# 11      1   12        4993              2566         106.573112
# 12      1   13        4224              2216         120.743676
# 13      1   14        4297              2278         124.538113
# ...

# %%
fp3 = df.pivot_table(index='day',columns='month',values='Page Views',aggfunc=np.sum,fill_value=0)

# %%
fp3
# Out:
# month     1     2     3
# day
# 1      3106  6156  5357
# 2      4944  6443  6016
# 3      6845  4887  5143
# 4      6653  4971  5500
# 5      6544  6260  6071
# 6      5231  6349  6247
# 7      4963  6121  5915
# 8      6140  6609  5804
# 9      6108  4947  5330
# 10     5588  4466  4260
# 11     5391  4645  4285
# 12     4993  6479  5996
# 13     4224  5518  6232
# 14     4297  5131  6461
# 15     6144  4830  6164
# 16     5920  5241  5733
# 17     5852  4601  5086
# 18     6331  4845  5510
# 19     5663  6147  7240
# 20     4503  6095  7365
# 21     4780  5726  6975
# 22     6654  4697  6895
# 23     6270  4420  7021
# 24     5911  4450  5496
# 25     6056  4583  5615
# 26     5705  5826  7379
# 27     4537  6406  7262
# 28     4580  5506  7139
# 29     6403     0  6767
# 30     6119     0  6585
# 31     6148     0  5704

# %%
plt.figure(figsize=(20,30))
visits = sns.heatmap(fp3,cmap='YlGn',linecolor='white',linewidth=1,annot=True,fmt='g')
visits.set_title("Visits per day")
# Out:
# Text(0.5,1,'Visits per day')

# %%
plt.figure(figsize=(10,10))
sns.distplot(df['Avg. Time on Page'],bins=20)
# Out:
# c:\users\mojiway\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x='Page Views',y='Avg. Time on Page',data=df,kind='kde')

# %%
visitRevenue = pd.read_excel('visit-revenue-Jan-Feb-Mar-2018.xlsx')

# %%
visitRevenue
# Out:
#     month  day  Page Views  Organic Searches  Avg. Time on Page  reveneueTHB
# 0       1    1        3106              1738         150.711111            0
# 1       1    2        4944              2535         112.363768            0
# 2       1    3        6845              3612         117.895123         2513
# 3       1    4        6653              3599         138.593058         4013
# 4       1    5        6544              3274         105.757796         7141
# 5       1    6        5231              2716         118.910029            0
# 6       1    7        4963              2513         113.705513            0
# 7       1    8        6140              3321         135.353093         6271
# 8       1    9        6108              3125         124.708286         7930
# 9       1   10        5588              2955         128.076455         7036
# 10      1   11        5391              2880         109.853411        11571
# ...

# %%
sns.jointplot(x='reveneueTHB',y='Page Views',data=visitRevenue,kind='hex')
# Out:
# c:\users\mojiway\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
perClass = pd.read_excel('sold-per-class.xlsx')

# %%
perClass
# Out:
#          1   2+  2  3+   3
# 2016  1185  263  3  41  38
# 2017   786  166  1  33  28
# 2018   199   45  0   5   2

# %%
plt.plot(data=perClass)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-149-4872618a5fb5> in <module>()
# ----> 1 plt.plot(data=perClass)
#
# c:\users\mojiway\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3356                       mplDeprecation)
#    3357     try:
# -> 3358         ret = ax.plot(*args, **kwargs)
#    3359     finally:
#    3360         ax._hold = washold
#
# c:\users\mojiway\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1792                     # update the information about replace names and
#    1793                     # label position
# -> 1794                     _arg_names = positional_parameter_names(args, data)
#    1795                     if (label_namer and  # we actually want a label here ...
# ...
